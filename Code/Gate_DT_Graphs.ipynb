# %%
import numpy as np
import matplotlib.pyplot as plt

cities = ["Chennai", "Delhi", "Mumbai"]

prediction_models = [
    "ExtraTrees", "GradientBoosting", "LinearRegression",
    "MovingAverage3", "MovingAverage7", "NaiveBlend",
    "Persistence", "PredictionAgentBest", "RandomForest",
    "Ridge", "SeasonalNaive7"
]

prediction_smape = {
    "Chennai": [4.696709, 4.800922, 69.449520, 8.692123, 7.091159,
                6.432578, 7.172545, 4.696709, 5.186724, 23.683753, 8.689615],
    "Delhi":   [5.173355, 5.074179, 17.947619, 5.048042, 5.256931,
                4.208925, 3.962857, 11.342058, 5.229965, 11.342058, 7.887770],
    "Mumbai":  [5.561477, 5.435085, 16.119339, 11.238843, 9.282519,
                7.769519, 7.446911, 5.561477, 5.911925, 14.357383, 11.020033],
}

routing_methods = [
    "AStar EcoRouting", "CARA Full", "CO2 Dijkstra",
    "GradientBoost EcoRoute", "MultiAgent NoNegotiation",
    "PredictiveDT Routing", "RandomForest EcoRoute",
    "ShortestPath", "SingleAgent Routing", "StaticDT Routing",
    "Weighted EcoRouting", "XGBoost EcoRoute"
]

operational_utility = {
    "Chennai": [-27.147282, 24.498076, -326.506006, -118.506729,
                -55.025029, -44.213512, -118.506729, 0.000000,
                -165.864710, -4.162119, -21.682465, -118.506729],
    "Delhi":   [-12.877850, 31.608623, -416.677059, -85.457927,
                5.007089, -29.267567, -85.457927, 0.000000,
                -118.407157, 24.537613, -0.761537, -85.457927],
    "Mumbai":  [0.110473, 23.633587, -234.977368, -51.520115,
                -17.527441, -20.923092, -51.520115, 0.000000,
                -109.615114, 14.789938, 1.503792, -51.520115],
}

policy_violation = {
    "Chennai": [7.868249, 0.000000, 38.223199, 17.303287,
                10.705206, 9.634500, 17.303287, 0.000000,
                22.089752, 5.385837, 7.297972, 17.303287],
    "Delhi":   [7.259549, 0.000000, 48.162289, 14.756282,
                5.320759, 8.992315, 14.756282, 0.000000,
                18.123662, 3.183601, 5.979730, 14.756282],
    "Mumbai":  [4.872409, 0.000000, 28.903205, 10.290553,
                6.741896, 7.092578, 10.290553, 0.000000,
                16.183188, 3.202138, 4.737076, 10.290553],
}

plt.rcParams.update({
    "font.family": "DejaVu Sans",
    "font.size": 16,
    "axes.titlesize": 22,
    "axes.labelsize": 20,
    "xtick.labelsize": 14,
    "ytick.labelsize": 16,
    "legend.fontsize": 15,
    "axes.linewidth": 1.35,
    "xtick.major.width": 1.25,
    "ytick.major.width": 1.25,
    "savefig.dpi": 900,
})

colors_a = {"Chennai": "red", "Delhi": "yellow", "Mumbai": "green"}
colors_b = {"Chennai": "fuchsia", "Delhi": "darkorchid", "Mumbai": "blue"}
colors_c = {"Chennai": "olive", "Delhi": "olivedrab", "Mumbai": "yellowgreen"}

fig, axes = plt.subplots(1, 3, figsize=(24, 8.4), constrained_layout=True)
bar_width = 0.24

# (a)
ax = axes[0]
x = np.arange(len(prediction_models))
for i, city in enumerate(cities):
    ax.bar(
        x + (i - 1) * bar_width,
        prediction_smape[city],
        width=bar_width,
        label=city,
        color=colors_a[city],
        edgecolor="black",
        linewidth=0.55,
        alpha=0.92,
    )

ax.set_title("(a) Prediction Error", fontweight="bold", fontsize=22)
ax.set_ylabel("sMAPE (%)", fontweight="bold", fontsize=20)
ax.set_xlabel("Prediction Model", fontweight="bold", fontsize=20)
ax.set_xticks(x)
ax.set_xticklabels(prediction_models, rotation=90, ha="center", va="top", fontweight="bold")
ax.grid(axis="y", linestyle="--", linewidth=0.8, alpha=0.35)
ax.set_axisbelow(True)
ax.legend(frameon=True, edgecolor="black", loc="upper right")

# (b)
ax = axes[1]
x = np.arange(len(routing_methods))
for i, city in enumerate(cities):
    ax.bar(
        x + (i - 1) * bar_width,
        operational_utility[city],
        width=bar_width,
        label=city,
        color=colors_b[city],
        edgecolor="black",
        linewidth=0.55,
        alpha=0.92,
    )

ax.axhline(0, color="black", linewidth=1.2)
ax.set_title("(b) Operational Utility", fontweight="bold", fontsize=22)
ax.set_ylabel("Utility Score", fontweight="bold", fontsize=20)
ax.set_xlabel("Routing Method", fontweight="bold", fontsize=20)
ax.set_xticks(x)
ax.set_xticklabels(routing_methods, rotation=90, ha="center", va="top", fontweight="bold")
ax.grid(axis="y", linestyle="--", linewidth=0.8, alpha=0.35)
ax.set_axisbelow(True)
ax.legend(frameon=True, edgecolor="black", loc="lower left")

# (c)
ax = axes[2]
x = np.arange(len(routing_methods))
for i, city in enumerate(cities):
    ax.bar(
        x + (i - 1) * bar_width,
        policy_violation[city],
        width=bar_width,
        label=city,
        color=colors_c[city],
        edgecolor="black",
        linewidth=0.55,
        alpha=0.92,
    )

ax.set_title("(c) Policy Violation", fontweight="bold", fontsize=22)
ax.set_ylabel("Mean Violation (%)", fontweight="bold", fontsize=20)
ax.set_xlabel("Routing Method", fontweight="bold", fontsize=20)
ax.set_xticks(x)
ax.set_xticklabels(routing_methods, rotation=90, ha="center", va="top", fontweight="bold")
ax.grid(axis="y", linestyle="--", linewidth=0.8, alpha=0.35)
ax.set_axisbelow(True)
ax.legend(frameon=True, edgecolor="black", loc="upper right")

for ax in axes:
    for spine in ax.spines.values():
        spine.set_linewidth(1.35)
        spine.set_color("black")

    ax.tick_params(axis="both", direction="out", length=5.5, width=1.25)

    for label in ax.get_yticklabels():
        label.set_fontweight("bold")

plt.savefig(
    "prediction_utility_policy_1x3_ieee_soft_colors_bold.png",
    dpi=900,
    bbox_inches="tight",
    facecolor="white"
)

plt.savefig(
    "prediction_utility_policy_1x3_ieee_soft_colors_bold.pdf",
    bbox_inches="tight",
    facecolor="white"
)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ============================================================
# Data
# ============================================================

cities = ["Chennai", "Delhi", "Mumbai"]

prediction_models = [
    "ExtraTrees", "GradientBoosting", "LinearRegression",
    "MovingAverage3", "MovingAverage7", "NaiveBlend",
    "Persistence", "PredictionAgentBest", "RandomForest",
    "Ridge", "SeasonalNaive7"
]

prediction_smape = {
    "Chennai": [4.696709, 4.800922, 69.449520, 8.692123, 7.091159,
                6.432578, 7.172545, 4.696709, 5.186724, 23.683753, 8.689615],
    "Delhi":   [5.173355, 5.074179, 17.947619, 5.048042, 5.256931,
                4.208925, 3.962857, 11.342058, 5.229965, 11.342058, 7.887770],
    "Mumbai":  [5.561477, 5.435085, 16.119339, 11.238843, 9.282519,
                7.769519, 7.446911, 5.561477, 5.911925, 14.357383, 11.020033],
}

routing_methods = [
    "AStar EcoRouting", "CARA Full", "CO2 Dijkstra",
    "GradientBoost EcoRoute", "MultiAgent NoNegotiation",
    "PredictiveDT Routing", "RandomForest EcoRoute",
    "ShortestPath", "SingleAgent Routing", "StaticDT Routing",
    "Weighted EcoRouting", "XGBoost EcoRoute"
]

operational_utility = {
    "Chennai": [-27.147282, 24.498076, -326.506006, -118.506729,
                -55.025029, -44.213512, -118.506729, 0.000000,
                -165.864710, -4.162119, -21.682465, -118.506729],
    "Delhi":   [-12.877850, 31.608623, -416.677059, -85.457927,
                5.007089, -29.267567, -85.457927, 0.000000,
                -118.407157, 24.537613, -0.761537, -85.457927],
    "Mumbai":  [0.110473, 23.633587, -234.977368, -51.520115,
                -17.527441, -20.923092, -51.520115, 0.000000,
                -109.615114, 14.789938, 1.503792, -51.520115],
}

policy_violation = {
    "Chennai": [7.868249, 0.000000, 38.223199, 17.303287,
                10.705206, 9.634500, 17.303287, 0.000000,
                22.089752, 5.385837, 7.297972, 17.303287],
    "Delhi":   [7.259549, 0.000000, 48.162289, 14.756282,
                5.320759, 8.992315, 14.756282, 0.000000,
                18.123662, 3.183601, 5.979730, 14.756282],
    "Mumbai":  [4.872409, 0.000000, 28.903205, 10.290553,
                6.741896, 7.092578, 10.290553, 0.000000,
                16.183188, 3.202138, 4.737076, 10.290553],
}

ablation_methods = [
    "CARA Full",
    "CARA without Hotspot",
    "CARA without Negotiation",
    "CARA without Policy",
    "CARA without Pollutant",
    "CARA without Prediction",
    "SingleAgent Routing",
    "StaticDT Routing",
]

ablation_utility = {
    "Chennai": [27.207704, 26.260585, 26.783200, -105.880252,
                26.906049, 25.398239, -165.864710, -4.162119],
    "Delhi":   [33.554280, 33.564238, 33.463446, -43.285132,
                33.506588, 33.279935, -118.407157, 24.537613],
    "Mumbai":  [26.571180, 25.211693, 26.666863, -61.193018,
                26.559325, 25.048212, -109.615114, 14.789938],
}

tradeoff_methods = [
    "AStar EcoRouting", "CARA Full", "CO2 Dijkstra",
    "GradientBoost EcoRoute", "MultiAgent NoNegotiation",
    "PredictiveDT Routing", "RandomForest EcoRoute",
    "ShortestPath", "SingleAgent Routing", "StaticDT Routing",
    "Weighted EcoRouting", "XGBoost EcoRoute"
]

tradeoff_distance = {
    "Chennai": [15.715634, 3.170727, 49.144732, 26.737994,
                18.680519, 18.013019, 26.737994, 0.000000,
                31.982358, 12.355555, 14.984028, 26.737994],
    "Delhi":   [15.563352, 3.933747, 59.718831, 24.760957,
                13.113751, 17.934410, 24.760957, 0.000000,
                28.229535, 10.235984, 13.834477, 24.760957],
    "Mumbai":  [12.710115, 3.444918, 39.789803, 19.224590,
                14.561098, 15.362443, 19.224590, 0.000000,
                26.023590, 9.930022, 12.523697, 19.224590],
}

tradeoff_co2 = {
    "Chennai": [47.143244, 21.640021, 55.240549, 51.719834,
                47.656321, 48.349971, 51.719834, 0.000000,
                52.812374, 44.538280, 46.732170, 51.719834],
    "Delhi":   [59.260806, 30.711734, 69.667858, 63.967637,
                57.363290, 61.119199, 63.967637, 0.000000,
                64.696616, 54.711764, 58.042036, 63.967637],
    "Mumbai":  [48.439326, 23.155597, 57.721682, 52.066550,
                49.320058, 49.992510, 52.066550, 0.000000,
                54.178060, 45.231977, 48.411939, 52.066550],
}

epsilons = [0.05, 0.10, 0.15, 0.20]
consensus_stability = {
    "Chennai": [0.623583, 0.674771, 0.715027, 0.742846],
    "Delhi":   [0.624821, 0.700119, 0.740495, 0.784549],
    "Mumbai":  [0.657095, 0.696267, 0.731742, 0.771582],
}

# ============================================================
# Plot style
# ============================================================

plt.rcParams.update({
    "font.family": "DejaVu Sans",
    "font.size": 15,
    "axes.titlesize": 21,
    "axes.labelsize": 19,
    "xtick.labelsize": 13,
    "ytick.labelsize": 15,
    "legend.fontsize": 13,
    "axes.linewidth": 1.35,
    "xtick.major.width": 1.25,
    "ytick.major.width": 1.25,
    "savefig.dpi": 900,
})

colors_a = {"Chennai": "red", "Delhi": "yellow", "Mumbai": "green"}
colors_b = {"Chennai": "fuchsia", "Delhi": "darkorchid", "Mumbai": "blue"}
colors_c = {"Chennai": "olive", "Delhi": "olivedrab", "Mumbai": "yellowgreen"}

colors_d = {"Chennai": "#6BAED6", "Delhi": "#FDAE6B", "Mumbai": "#74C476"}
colors_e = {
    "AStar EcoRouting": "#1F77B4",
    "CARA Full": "#E6550D",
    "CO2 Dijkstra": "#31A354",
    "GradientBoost EcoRoute": "#756BB1",
    "MultiAgent NoNegotiation": "#636363",
    "PredictiveDT Routing": "#E377C2",
    "RandomForest EcoRoute": "#17BECF",
    "ShortestPath": "#000000",
    "SingleAgent Routing": "#BCBD22",
    "StaticDT Routing": "#8C564B",
    "Weighted EcoRouting": "#FF9896",
    "XGBoost EcoRoute": "#9ECAE1",
}
colors_f = {"Chennai": "brown", "Delhi": "tomato", "Mumbai": "salmon"}

fig, axes = plt.subplots(2, 3, figsize=(25, 15.8), constrained_layout=True)
bar_width = 0.24

# ============================================================
# (a) Prediction Error
# ============================================================

ax = axes[0, 0]
x = np.arange(len(prediction_models))

for i, city in enumerate(cities):
    ax.bar(
        x + (i - 1) * bar_width,
        prediction_smape[city],
        width=bar_width,
        label=city,
        color=colors_a[city],
        edgecolor="black",
        linewidth=0.55,
        alpha=0.92,
    )

ax.set_title("(a) Prediction Error", fontweight="bold")
ax.set_ylabel("sMAPE (%)", fontweight="bold")
ax.set_xlabel("Prediction Model", fontweight="bold")
ax.set_xticks(x)
ax.set_xticklabels(prediction_models, rotation=90, ha="center", va="top", fontweight="bold")
ax.grid(axis="y", linestyle="--", linewidth=0.8, alpha=0.35)
ax.set_axisbelow(True)
ax.legend(frameon=True, edgecolor="black", loc="upper right")

# ============================================================
# (b) Operational Utility
# ============================================================

ax = axes[0, 1]
x = np.arange(len(routing_methods))

for i, city in enumerate(cities):
    ax.bar(
        x + (i - 1) * bar_width,
        operational_utility[city],
        width=bar_width,
        label=city,
        color=colors_b[city],
        edgecolor="black",
        linewidth=0.55,
        alpha=0.92,
    )

ax.axhline(0, color="black", linewidth=1.2)
ax.set_title("(b) Operational Utility", fontweight="bold")
ax.set_ylabel("Utility Score", fontweight="bold")
ax.set_xlabel("Routing Method", fontweight="bold")
ax.set_xticks(x)
ax.set_xticklabels(routing_methods, rotation=90, ha="center", va="top", fontweight="bold")
ax.grid(axis="y", linestyle="--", linewidth=0.8, alpha=0.35)
ax.set_axisbelow(True)
ax.legend(frameon=True, edgecolor="black", loc="lower left")

# ============================================================
# (c) Policy Violation
# ============================================================

ax = axes[0, 2]
x = np.arange(len(routing_methods))

for i, city in enumerate(cities):
    ax.bar(
        x + (i - 1) * bar_width,
        policy_violation[city],
        width=bar_width,
        label=city,
        color=colors_c[city],
        edgecolor="black",
        linewidth=0.55,
        alpha=0.92,
    )

ax.set_title("(c) Policy Violation", fontweight="bold")
ax.set_ylabel("Mean Violation (%)", fontweight="bold")
ax.set_xlabel("Routing Method", fontweight="bold")
ax.set_xticks(x)
ax.set_xticklabels(routing_methods, rotation=90, ha="center", va="top", fontweight="bold")
ax.grid(axis="y", linestyle="--", linewidth=0.8, alpha=0.35)
ax.set_axisbelow(True)
ax.legend(frameon=True, edgecolor="black", loc="upper right")

# ============================================================
# (d) Agent Ablation
# ============================================================

ax = axes[1, 0]
x = np.arange(len(ablation_methods))

for i, city in enumerate(cities):
    ax.bar(
        x + (i - 1) * bar_width,
        ablation_utility[city],
        width=bar_width,
        label=city,
        color=colors_d[city],
        edgecolor="black",
        linewidth=0.55,
        alpha=0.95,
    )

ax.axhline(0, color="black", linewidth=1.2)
ax.set_title("(d) Agent Ablation", fontweight="bold")
ax.set_ylabel("Operational Utility", fontweight="bold")
ax.set_xlabel("Ablation Setting", fontweight="bold")
ax.set_xticks(x)
ax.set_xticklabels(ablation_methods, rotation=90, ha="center", va="top", fontweight="bold")
ax.grid(axis="y", linestyle="--", linewidth=0.8, alpha=0.35)
ax.set_axisbelow(True)
ax.legend(frameon=True, edgecolor="black", loc="lower left")

# ============================================================
# (e) Routing Trade-off
# ============================================================

ax = axes[1, 1]

for method_idx, method in enumerate(tradeoff_methods):
    xs = [tradeoff_distance[city][method_idx] for city in cities]
    ys = [tradeoff_co2[city][method_idx] for city in cities]

    ax.scatter(
        xs,
        ys,
        s=115,
        color=colors_e[method],
        edgecolor="black",
        linewidth=0.55,
        alpha=0.90,
        label=method,
    )

ax.axhline(0, color="black", linewidth=1.0)
ax.axvline(0, color="black", linewidth=1.0)
ax.set_title("(e) Routing Trade-off", fontweight="bold")
ax.set_xlabel("Distance Penalty (%)", fontweight="bold")
ax.set_ylabel("CO$_2$ Reduction (%)", fontweight="bold")
ax.grid(True, linestyle="--", linewidth=0.8, alpha=0.35)
ax.set_axisbelow(True)
ax.legend(
    frameon=True,
    edgecolor="black",
    fontsize=9,
    loc="center left",
    bbox_to_anchor=(1.02, 0.5),
    borderaxespad=0.0,
)

# ============================================================
# (f) Consensus Stability
# ============================================================

ax = axes[1, 2]

markers = {"Chennai": "o", "Delhi": "s", "Mumbai": "^"}

for city in cities:
    ax.plot(
        epsilons,
        consensus_stability[city],
        marker=markers[city],
        markersize=9,
        linewidth=3.0,
        color=colors_f[city],
        label=city,
    )

ax.set_title("(f) Consensus Stability", fontweight="bold")
ax.set_xlabel("Epsilon", fontweight="bold")
ax.set_ylabel("Consensus Stability", fontweight="bold")
ax.set_xticks(epsilons)
ax.grid(True, linestyle="--", linewidth=0.8, alpha=0.35)
ax.set_axisbelow(True)
ax.legend(frameon=True, edgecolor="black", loc="upper left")

# ============================================================
# Final formatting
# ============================================================

for ax in axes.flat:
    for spine in ax.spines.values():
        spine.set_linewidth(1.35)
        spine.set_color("black")

    ax.tick_params(axis="both", direction="out", length=5.5, width=1.25)

    for label in ax.get_yticklabels():
        label.set_fontweight("bold")

plt.savefig(
    "gate_dt_cara_results_2x3_ieee.png",
    dpi=900,
    bbox_inches="tight",
    facecolor="white"
)

plt.savefig(
    "gate_dt_cara_results_2x3_ieee.pdf",
    bbox_inches="tight",
    facecolor="white"
)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ============================================================
# Data
# ============================================================

cities = ["Chennai", "Delhi", "Mumbai"]

prediction_models = [
    "ExtraTrees", "GradientBoosting", "LinearRegression",
    "MovingAverage3", "MovingAverage7", "NaiveBlend",
    "Persistence", "PredictionAgentBest", "RandomForest",
    "Ridge", "SeasonalNaive7"
]

prediction_smape = {
    "Chennai": [4.696709, 4.800922, 69.449520, 8.692123, 7.091159,
                6.432578, 7.172545, 4.696709, 5.186724, 23.683753, 8.689615],
    "Delhi":   [5.173355, 5.074179, 17.947619, 5.048042, 5.256931,
                4.208925, 3.962857, 11.342058, 5.229965, 11.342058, 7.887770],
    "Mumbai":  [5.561477, 5.435085, 16.119339, 11.238843, 9.282519,
                7.769519, 7.446911, 5.561477, 5.911925, 14.357383, 11.020033],
}

routing_methods = [
    "AStar EcoRouting", "CARA Full", "CO2 Dijkstra",
    "GradientBoost EcoRoute", "MultiAgent NoNegotiation",
    "PredictiveDT Routing", "RandomForest EcoRoute",
    "ShortestPath", "SingleAgent Routing", "StaticDT Routing",
    "Weighted EcoRouting", "XGBoost EcoRoute"
]

operational_utility = {
    "Chennai": [-27.147282, 24.498076, -326.506006, -118.506729,
                -55.025029, -44.213512, -118.506729, 0.000000,
                -165.864710, -4.162119, -21.682465, -118.506729],
    "Delhi":   [-12.877850, 31.608623, -416.677059, -85.457927,
                5.007089, -29.267567, -85.457927, 0.000000,
                -118.407157, 24.537613, -0.761537, -85.457927],
    "Mumbai":  [0.110473, 23.633587, -234.977368, -51.520115,
                -17.527441, -20.923092, -51.520115, 0.000000,
                -109.615114, 14.789938, 1.503792, -51.520115],
}

policy_violation = {
    "Chennai": [7.868249, 0.000000, 38.223199, 17.303287,
                10.705206, 9.634500, 17.303287, 0.000000,
                22.089752, 5.385837, 7.297972, 17.303287],
    "Delhi":   [7.259549, 0.000000, 48.162289, 14.756282,
                5.320759, 8.992315, 14.756282, 0.000000,
                18.123662, 3.183601, 5.979730, 14.756282],
    "Mumbai":  [4.872409, 0.000000, 28.903205, 10.290553,
                6.741896, 7.092578, 10.290553, 0.000000,
                16.183188, 3.202138, 4.737076, 10.290553],
}

ablation_methods = [
    "CARA Full",
    "CARA without Hotspot",
    "CARA without Negotiation",
    "CARA without Policy",
    "CARA without Pollutant",
    "CARA without Prediction",
    "SingleAgent Routing",
    "StaticDT Routing",
]

ablation_utility = {
    "Chennai": [27.207704, 26.260585, 26.783200, -105.880252,
                26.906049, 25.398239, -165.864710, -4.162119],
    "Delhi":   [33.554280, 33.564238, 33.463446, -43.285132,
                33.506588, 33.279935, -118.407157, 24.537613],
    "Mumbai":  [26.571180, 25.211693, 26.666863, -61.193018,
                26.559325, 25.048212, -109.615114, 14.789938],
}

tradeoff_methods = [
    "AStar EcoRouting", "CARA Full", "CO2 Dijkstra",
    "GradientBoost EcoRoute", "MultiAgent NoNegotiation",
    "PredictiveDT Routing", "RandomForest EcoRoute",
    "ShortestPath", "SingleAgent Routing", "StaticDT Routing",
    "Weighted EcoRouting", "XGBoost EcoRoute"
]

tradeoff_distance = {
    "Chennai": [15.715634, 3.170727, 49.144732, 26.737994,
                18.680519, 18.013019, 26.737994, 0.000000,
                31.982358, 12.355555, 14.984028, 26.737994],
    "Delhi":   [15.563352, 3.933747, 59.718831, 24.760957,
                13.113751, 17.934410, 24.760957, 0.000000,
                28.229535, 10.235984, 13.834477, 24.760957],
    "Mumbai":  [12.710115, 3.444918, 39.789803, 19.224590,
                14.561098, 15.362443, 19.224590, 0.000000,
                26.023590, 9.930022, 12.523697, 19.224590],
}

tradeoff_co2 = {
    "Chennai": [47.143244, 21.640021, 55.240549, 51.719834,
                47.656321, 48.349971, 51.719834, 0.000000,
                52.812374, 44.538280, 46.732170, 51.719834],
    "Delhi":   [59.260806, 30.711734, 69.667858, 63.967637,
                57.363290, 61.119199, 63.967637, 0.000000,
                64.696616, 54.711764, 58.042036, 63.967637],
    "Mumbai":  [48.439326, 23.155597, 57.721682, 52.066550,
                49.320058, 49.992510, 52.066550, 0.000000,
                54.178060, 45.231977, 48.411939, 52.066550],
}

epsilons = [0.05, 0.10, 0.15, 0.20]
consensus_stability = {
    "Chennai": [0.623583, 0.674771, 0.715027, 0.742846],
    "Delhi":   [0.624821, 0.700119, 0.740495, 0.784549],
    "Mumbai":  [0.657095, 0.696267, 0.731742, 0.771582],
}

# ============================================================
# Plot style
# ============================================================

plt.rcParams.update({
    "font.family": "DejaVu Sans",
    "font.size": 15,
    "axes.titlesize": 21,
    "axes.labelsize": 19,
    "xtick.labelsize": 13,
    "ytick.labelsize": 15,
    "legend.fontsize": 13,
    "axes.linewidth": 1.35,
    "xtick.major.width": 1.25,
    "ytick.major.width": 1.25,
    "savefig.dpi": 900,
})

colors_a = {"Chennai": "red", "Delhi": "yellow", "Mumbai": "green"}
colors_b = {"Chennai": "fuchsia", "Delhi": "darkorchid", "Mumbai": "blue"}
colors_c = {"Chennai": "olive", "Delhi": "olivedrab", "Mumbai": "yellowgreen"}

# Updated second-row colors using named matplotlib colors
colors_d = {"Chennai": "lightskyblue", "Delhi": "sandybrown", "Mumbai": "mediumseagreen"}

colors_e = {
    "AStar EcoRouting": "royalblue",
    "CARA Full": "darkorange",
    "CO2 Dijkstra": "forestgreen",
    "GradientBoost EcoRoute": "rebeccapurple",
    "MultiAgent NoNegotiation": "slategrey",
    "PredictiveDT Routing": "hotpink",
    "RandomForest EcoRoute": "cyan",
    "ShortestPath": "black",
    "SingleAgent Routing": "gold",
    "StaticDT Routing": "teal",
    "Weighted EcoRouting": "lightcoral",
    "XGBoost EcoRoute": "deepskyblue",
}

colors_f = {"Chennai": "crimson", "Delhi": "darkorange", "Mumbai": "seagreen"}

fig, axes = plt.subplots(2, 3, figsize=(25, 15.8), constrained_layout=True)
bar_width = 0.24

# ============================================================
# (a) Prediction Error
# ============================================================

ax = axes[0, 0]
x = np.arange(len(prediction_models))

for i, city in enumerate(cities):
    ax.bar(
        x + (i - 1) * bar_width,
        prediction_smape[city],
        width=bar_width,
        label=city,
        color=colors_a[city],
        edgecolor="black",
        linewidth=0.55,
        alpha=0.92,
    )

ax.set_title("(a) Prediction Error", fontweight="bold")
ax.set_ylabel("sMAPE (%)", fontweight="bold")
ax.set_xlabel("Prediction Model", fontweight="bold")
ax.set_xticks(x)
ax.set_xticklabels(prediction_models, rotation=90, ha="center", va="top", fontweight="bold")
ax.grid(axis="y", linestyle="--", linewidth=0.8, alpha=0.35)
ax.set_axisbelow(True)
ax.legend(frameon=True, edgecolor="black", loc="upper right")

# ============================================================
# (b) Operational Utility
# ============================================================

ax = axes[0, 1]
x = np.arange(len(routing_methods))

for i, city in enumerate(cities):
    ax.bar(
        x + (i - 1) * bar_width,
        operational_utility[city],
        width=bar_width,
        label=city,
        color=colors_b[city],
        edgecolor="black",
        linewidth=0.55,
        alpha=0.92,
    )

ax.axhline(0, color="black", linewidth=1.2)
ax.set_title("(b) Operational Utility", fontweight="bold")
ax.set_ylabel("Utility Score", fontweight="bold")
ax.set_xlabel("Routing Method", fontweight="bold")
ax.set_xticks(x)
ax.set_xticklabels(routing_methods, rotation=90, ha="center", va="top", fontweight="bold")
ax.grid(axis="y", linestyle="--", linewidth=0.8, alpha=0.35)
ax.set_axisbelow(True)
ax.legend(frameon=True, edgecolor="black", loc="lower left")

# ============================================================
# (c) Policy Violation
# ============================================================

ax = axes[0, 2]
x = np.arange(len(routing_methods))

for i, city in enumerate(cities):
    ax.bar(
        x + (i - 1) * bar_width,
        policy_violation[city],
        width=bar_width,
        label=city,
        color=colors_c[city],
        edgecolor="black",
        linewidth=0.55,
        alpha=0.92,
    )

ax.set_title("(c) Policy Violation", fontweight="bold")
ax.set_ylabel("Mean Violation (%)", fontweight="bold")
ax.set_xlabel("Routing Method", fontweight="bold")
ax.set_xticks(x)
ax.set_xticklabels(routing_methods, rotation=90, ha="center", va="top", fontweight="bold")
ax.grid(axis="y", linestyle="--", linewidth=0.8, alpha=0.35)
ax.set_axisbelow(True)
ax.legend(frameon=True, edgecolor="black", loc="upper right")

# ============================================================
# (d) Agent Ablation
# ============================================================

ax = axes[1, 0]
x = np.arange(len(ablation_methods))

for i, city in enumerate(cities):
    ax.bar(
        x + (i - 1) * bar_width,
        ablation_utility[city],
        width=bar_width,
        label=city,
        color=colors_d[city],
        edgecolor="black",
        linewidth=0.55,
        alpha=0.95,
    )

ax.axhline(0, color="black", linewidth=1.2)
ax.set_title("(d) Agent Ablation", fontweight="bold")
ax.set_ylabel("Operational Utility", fontweight="bold")
ax.set_xlabel("Ablation Setting", fontweight="bold")
ax.set_xticks(x)
ax.set_xticklabels(ablation_methods, rotation=90, ha="center", va="top", fontweight="bold")
ax.grid(axis="y", linestyle="--", linewidth=0.8, alpha=0.35)
ax.set_axisbelow(True)
ax.legend(frameon=True, edgecolor="black", loc="lower left")

# ============================================================
# (e) Routing Trade-off
# ============================================================

ax = axes[1, 1]

markers_tradeoff = ["o", "s", "^", "D", "P", "X", "v", "*", "<", ">", "h", "p"]

for method_idx, method in enumerate(tradeoff_methods):
    xs = [tradeoff_distance[city][method_idx] for city in cities]
    ys = [tradeoff_co2[city][method_idx] for city in cities]

    ax.scatter(
        xs,
        ys,
        s=150 if method != "CARA Full" else 220,
        marker=markers_tradeoff[method_idx],
        color=colors_e[method],
        edgecolor="black",
        linewidth=0.70,
        alpha=0.90,
        label=method,
    )

ax.axhline(0, color="black", linewidth=1.0)
ax.axvline(0, color="black", linewidth=1.0)
ax.set_title("(e) Routing Trade-off", fontweight="bold")
ax.set_xlabel("Distance Penalty (%)", fontweight="bold")
ax.set_ylabel("CO$_2$ Reduction (%)", fontweight="bold")
ax.grid(True, linestyle="--", linewidth=0.8, alpha=0.35)
ax.set_axisbelow(True)
ax.legend(
    frameon=True,
    edgecolor="black",
    fontsize=9,
    loc="center left",
    bbox_to_anchor=(1.02, 0.5),
    borderaxespad=0.0,
)

# ============================================================
# (f) Consensus Stability
# ============================================================

ax = axes[1, 2]

line_styles = {"Chennai": "-", "Delhi": "--", "Mumbai": "-."}

for city in cities:
    ax.plot(
        epsilons,
        consensus_stability[city],
        marker="*",
        markersize=16,
        linewidth=3.2,
        linestyle=line_styles[city],
        color=colors_f[city],
        markeredgecolor="black",
        markeredgewidth=0.75,
        label=city,
    )

ax.set_title("(f) Consensus Stability", fontweight="bold")
ax.set_xlabel("Epsilon", fontweight="bold")
ax.set_ylabel("Consensus Stability", fontweight="bold")
ax.set_xticks(epsilons)
ax.grid(True, linestyle="--", linewidth=0.8, alpha=0.35)
ax.set_axisbelow(True)
ax.legend(frameon=True, edgecolor="black", loc="upper left")

# ============================================================
# Final formatting
# ============================================================

for ax in axes.flat:
    for spine in ax.spines.values():
        spine.set_linewidth(1.35)
        spine.set_color("black")

    ax.tick_params(axis="both", direction="out", length=5.5, width=1.25)

    for label in ax.get_yticklabels():
        label.set_fontweight("bold")

plt.savefig(
    "gate_dt_cara_results_2x3_ieee_updated.png",
    dpi=900,
    bbox_inches="tight",
    facecolor="white"
)

plt.savefig(
    "gate_dt_cara_results_2x3_ieee_updated.pdf",
    bbox_inches="tight",
    facecolor="white"
)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

epsilons = [0.05, 0.10, 0.15, 0.20]

decision_time = {
    "Chennai": [1.78, 2.30, 2.25, 2.24],
    "Delhi":   [11.25, 10.52, 11.25, 11.05],
    "Mumbai":  [2.03, 1.42, 1.20, 1.20],
}

cities = list(decision_time.keys())
x = np.arange(len(epsilons))
bar_width = 0.22

fig, ax = plt.subplots(figsize=(10, 5.8), dpi=600)

hatches = ["///", "\\\\\\", "xx"]

for i, city in enumerate(cities):
    ax.bar(
        x + (i - 1) * bar_width,
        decision_time[city],
        width=bar_width,
        label=city,
        edgecolor="black",
        linewidth=1.2,
        hatch=hatches[i],
        alpha=0.95,
        zorder=3
    )

ax.set_xlabel("Epsilon", fontsize=16, fontweight="bold")
ax.set_ylabel("Seconds Per Route", fontsize=16, fontweight="bold")
ax.set_title("CARA Decision Time", fontsize=18, fontweight="bold", pad=22)

ax.set_xticks(x)
ax.set_xticklabels(
    [str(e) for e in epsilons],
    rotation=90,
    fontsize=14,
    fontweight="bold"
)

ax.tick_params(axis="y", labelsize=14, width=1.2)
for label in ax.get_yticklabels():
    label.set_fontweight("bold")

# Extra top margin so legend does not overlap bars
ax.set_ylim(0, 13.0)

# Legend placed above plot area, below title
ax.legend(
    title="City",
    title_fontsize=13,
    fontsize=12,
    frameon=True,
    edgecolor="black",
    loc="upper center",
    bbox_to_anchor=(0.5, 1.02),
    ncol=3,
    borderaxespad=0.4
)

ax.grid(axis="y", linestyle="--", linewidth=0.8, alpha=0.45, zorder=0)

for spine in ax.spines.values():
    spine.set_linewidth(1.2)

plt.tight_layout(rect=[0, 0, 1, 0.95])

plt.savefig(
    "cara_decision_time.png",
    dpi=600,
    bbox_inches="tight",
    pad_inches=0.05
)

plt.savefig(
    "cara_decision_time.pdf",
    dpi=600,
    bbox_inches="tight",
    pad_inches=0.05
)

plt.show()
